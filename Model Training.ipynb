# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\PC'

# %%
os.chdir(r"D:\FQL\PJ 3")

# %% [markdown]
# ##  Section 1: Import Libraries

# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import joblib, os

# %%
# Stats
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
import pmdarima as pm

# %%
pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.1.1-cp313-cp313-win_amd64.whl.metadata (8.5 kB)
# Requirement already satisfied: joblib>=0.11 in d:\downloads\anacondasoft\lib\site-packages (from pmdarima) (1.4.2)
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29 (from pmdarima)
#   Downloading cython-3.2.4-cp313-cp313-win_amd64.whl.metadata (7.7 kB)
# Requirement already satisfied: numpy>=1.21.6 in d:\downloads\anacondasoft\lib\site-packages (from pmdarima) (2.1.3)
# Requirement already satisfied: pandas>=0.19 in d:\downloads\anacondasoft\lib\site-packages (from pmdarima) (2.2.3)
# Requirement already satisfied: scikit-learn>=0.22 in d:\downloads\anacondasoft\lib\site-packages (from pmdarima) (1.7.2)
# Requirement already satisfied: scipy>=1.13.0 in d:\downloads\anacondasoft\lib\site-packages (from pmdarima) (1.15.3)
# Collecting statsmodels>=0.14.5 (from pmdarima)
#   Downloading statsmodels-0.14.6-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: urllib3 in d:\downloads\anacondasoft\lib\site-packages (from pmdarima) (2.3.0)
# Requirement already satisfied: setuptools!=50.0.0,>=42 in d:\downloads\anacondasoft\lib\site-packages (from pmdarima) (72.1.0)
# Requirement already satisfied: packaging>=17.1 in d:\downloads\anacondasoft\lib\site-packages (from pmdarima) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\downloads\anacondasoft\lib\site-packages (from pandas>=0.19->pmdarima) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\downloads\anacondasoft\lib\site-packages (from pandas>=0.19->pmdarima) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\downloads\anacondasoft\lib\site-packages (from pandas>=0.19->pmdarima) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\downloads\anacondasoft\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.19->pmdarima) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\downloads\anacondasoft\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in d:\downloads\anacondasoft\lib\site-packages (from statsmodels>=0.14.5->pmdarima) (1.0.1)
# Downloading pmdarima-2.1.1-cp313-cp313-win_amd64.whl (711 kB)
#    ---------------------------------------- 0.0/711.9 kB ? eta -:--:--
#    ----------------------------- ---------- 524.3/711.9 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 711.9/711.9 kB 3.4 MB/s eta 0:00:00
# Downloading cython-3.2.4-cp313-cp313-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.8/2.8 MB 4.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.6/2.8 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 4.5 MB/s eta 0:00:00
# Downloading statsmodels-0.14.6-cp313-cp313-win_amd64.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.5 MB 3.8 MB/s eta 0:00:03
#    ------- -------------------------------- 1.8/9.5 MB 4.7 MB/s eta 0:00:02
#    ------------ --------------------------- 2.9/9.5 MB 4.7 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.9/9.5 MB 4.8 MB/s eta 0:00:02
#    --------------------- ------------------ 5.2/9.5 MB 4.9 MB/s eta 0:00:01
#    ------------------------- -------------- 6.0/9.5 MB 4.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.8/9.5 MB 4.6 MB/s eta 0:00:01
#    -------------------------------- ------- 7.9/9.5 MB 4.6 MB/s eta 0:00:01
#    ------------------------------------ --- 8.7/9.5 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 4.4 MB/s eta 0:00:00
# Installing collected packages: Cython, statsmodels, pmdarima
#
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#   Attempting uninstall: statsmodels
#    ---------------------------------------- 0/3 [Cython]
#     Found existing installation: statsmodels 0.14.4
#    ---------------------------------------- 0/3 [Cython]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#     Uninstalling statsmodels-0.14.4:
#    ------------- -------------------------- 1/3 [statsmodels]
#       Successfully uninstalled statsmodels-0.14.4
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    -------------------------- ------------- 2/3 [pmdarima]
#    -------------------------- ------------- 2/3 [pmdarima]
#    -------------------------- ------------- 2/3 [pmdarima]
#    -------------------------- ------------- 2/3 [pmdarima]
#    -------------------------- ------------- 2/3 [pmdarima]
#    -------------------------- ------------- 2/3 [pmdarima]
#    -------------------------- ------------- 2/3 [pmdarima]
#    -------------------------- ------------- 2/3 [pmdarima]
#    -------------------------- ------------- 2/3 [pmdarima]
#    -------------------------- ------------- 2/3 [pmdarima]
#    -------------------------- ------------- 2/3 [pmdarima]
#    -------------------------- ------------- 2/3 [pmdarima]
#    ---------------------------------------- 3/3 [pmdarima]
#
# Successfully installed Cython-3.2.4 pmdarima-2.1.1 statsmodels-0.14.6
# Note: you may need to restart the kernel to use updated packages.

# %%
# ML
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import xgboost as xgb
import lightgbm as lgb

# %%
# Deep Learning
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
# Prophet
from prophet import Prophet

# %%
pip install prophet
# Out:
# Collecting prophet
#   Downloading prophet-1.3.0-py3-none-win_amd64.whl.metadata (3.6 kB)
# Collecting cmdstanpy>=1.0.4 (from prophet)
#   Downloading cmdstanpy-1.3.0-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: numpy>=1.15.4 in d:\downloads\anacondasoft\lib\site-packages (from prophet) (2.1.3)
# Requirement already satisfied: matplotlib>=2.0.0 in d:\downloads\anacondasoft\lib\site-packages (from prophet) (3.10.0)
# Requirement already satisfied: pandas>=1.0.4 in d:\downloads\anacondasoft\lib\site-packages (from prophet) (2.2.3)
# Collecting holidays<1,>=0.25 (from prophet)
#   Downloading holidays-0.91-py3-none-any.whl.metadata (50 kB)
# Requirement already satisfied: tqdm>=4.36.1 in d:\downloads\anacondasoft\lib\site-packages (from prophet) (4.67.1)
# Requirement already satisfied: importlib_resources in d:\downloads\anacondasoft\lib\site-packages (from prophet) (6.5.2)
# Requirement already satisfied: python-dateutil<3,>=2.9.0.post0 in d:\downloads\anacondasoft\lib\site-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\downloads\anacondasoft\lib\site-packages (from python-dateutil<3,>=2.9.0.post0->holidays<1,>=0.25->prophet) (1.17.0)
# Collecting stanio<2.0.0,>=0.4.0 (from cmdstanpy>=1.0.4->prophet)
#   Downloading stanio-0.5.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in d:\downloads\anacondasoft\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in d:\downloads\anacondasoft\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\downloads\anacondasoft\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\downloads\anacondasoft\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in d:\downloads\anacondasoft\lib\site-packages (from matplotlib>=2.0.0->prophet) (24.2)
# Requirement already satisfied: pillow>=8 in d:\downloads\anacondasoft\lib\site-packages (from matplotlib>=2.0.0->prophet) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\downloads\anacondasoft\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.2.0)
# Requirement already satisfied: pytz>=2020.1 in d:\downloads\anacondasoft\lib\site-packages (from pandas>=1.0.4->prophet) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\downloads\anacondasoft\lib\site-packages (from pandas>=1.0.4->prophet) (2025.2)
# Requirement already satisfied: colorama in d:\downloads\anacondasoft\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)
# Downloading prophet-1.3.0-py3-none-win_amd64.whl (12.1 MB)
#    ---------------------------------------- 0.0/12.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/12.1 MB 5.4 MB/s eta 0:00:03
#    ------ --------------------------------- 1.8/12.1 MB 4.9 MB/s eta 0:00:03
#    --------- ------------------------------ 2.9/12.1 MB 5.1 MB/s eta 0:00:02
#    ------------- -------------------------- 4.2/12.1 MB 5.3 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.2/12.1 MB 5.4 MB/s eta 0:00:02
#    --------------------- ------------------ 6.6/12.1 MB 5.5 MB/s eta 0:00:02
#    ------------------------- -------------- 7.6/12.1 MB 5.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.9/12.1 MB 5.5 MB/s eta 0:00:01
#    -------------------------------- ------- 10.0/12.1 MB 5.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.7/12.1 MB 5.3 MB/s eta 0:00:01
#    -------------------------------------- - 11.8/12.1 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 12.1/12.1 MB 5.2 MB/s eta 0:00:00
# Downloading holidays-0.91-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------- ----------------- 0.8/1.4 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 4.5 MB/s eta 0:00:00
# Downloading cmdstanpy-1.3.0-py3-none-any.whl (99 kB)
# Downloading stanio-0.5.1-py3-none-any.whl (8.1 kB)
# Installing collected packages: stanio, holidays, cmdstanpy, prophet
#
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    ---------- ----------------------------- 1/4 [holidays]
#    -------------------- ------------------- 2/4 [cmdstanpy]
#    -------------------- ------------------- 2/4 [cmdstanpy]
#    -------------------- ------------------- 2/4 [cmdstanpy]
#    -------------------- ------------------- 2/4 [cmdstanpy]
#    -------------------- ------------------- 2/4 [cmdstanpy]
#    -------------------- ------------------- 2/4 [cmdstanpy]
#    ------------------------------ --------- 3/4 [prophet]
#    ------------------------------ --------- 3/4 [prophet]
#    ------------------------------ --------- 3/4 [prophet]
#    ------------------------------ --------- 3/4 [prophet]
#    ------------------------------ --------- 3/4 [prophet]
#    ------------------------------ --------- 3/4 [prophet]
#    ---------------------------------------- 4/4 [prophet]
#
# Successfully installed cmdstanpy-1.3.0 holidays-0.91 prophet-1.3.0 stanio-0.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
os.makedirs('models', exist_ok=True)
os.makedirs('predictions', exist_ok=True)

# %% [markdown]
# ## Section 2: Load Dataset

# %%
# Load dataset 
try:
    df = pd.read_csv('BTC_cleaned.csv', index_col='Date', parse_dates=True)
    print("Loaded cleaned data from Notebook 1")
except FileNotFoundError:
    df = pd.read_csv('BTC-USD.csv', index_col='Date', parse_dates=True)  # UPDATE THIS PATH
    print(" Loaded raw data (will clean in this notebook)")
# Out:
# Loaded cleaned data from Notebook 1
