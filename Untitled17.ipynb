# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\PC'

# %%
os.chdir(r"D:\FQL\PJ 3")

# %% [markdown]
# ## Section 1 : Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from statsmodels.tsa.stattools import adfuller, kpss
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from scipy import stats

plt.rcParams['figure.figsize'] = (14, 5)
plt.rcParams['axes.grid'] = True
plt.rcParams['grid.alpha'] = 0.3
sns.set_theme(style='darkgrid')

# %% [markdown]
# ## Section 2 : Load Data set

# %%
data = pd.read_csv('BTC-USD.csv')

print(f"\nDataset Shape: {data.shape[0]:,} rows × {data.shape[1]} columns")
print(f"Memory Usage: {data.memory_usage(deep=True).sum() / 1024**2:.2f} MB")
# Out:
# Dataset Shape: 3,566 rows × 7 columns
# Memory Usage: 0.36 MB

# %%
# Display first few rows
print("\nFirst 5 rows of the dataset:")
data.head()
# Out:
# First 5 rows of the dataset:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  10-10-2014  364.687012  375.066986  352.963013  361.562012  361.562012
# 1  11-10-2014  361.362000  367.191010  355.950989  362.299011  362.299011
# 2  12-10-2014  362.605988  379.433014  356.144012  378.549011  378.549011
# 3  13-10-2014  377.920990  397.226013  368.897003  390.414001  390.414001
# 4  14-10-2014  391.691986  411.697998  391.324005  400.869995  400.869995
#
#        Volume
# 0  43665700.0
# 1  13345200.0
# 2  17552800.0
# 3  35221400.0
# 4  38491500.0

# %%
# Display last few rows
print("\nLast 5 rows of the dataset:")
data.tail()
# Out:
# Last 5 rows of the dataset:
#             Date         Open         High          Low        Close  \
# 3561  10-07-2024  58033.88281  59359.43359  57178.41406  57742.49609
# 3562  11-07-2024  57729.89063  59299.43359  57120.37891  57344.91406
# 3563  12-07-2024  57341.19531  58532.55469  56590.17578  57899.46484
# 3564  13-07-2024  57908.73828  59787.07813  57796.44141  59231.95313
# 3565  14-07-2024  59225.25000  60363.85938  59225.25000  60245.80469
#
#         Adj Close        Volume
# 3561  57742.49609  2.617526e+10
# 3562  57344.91406  2.870780e+10
# 3563  57899.46484  2.560481e+10
# 3564  59231.95313  1.708006e+10
# 3565  60245.80469  2.140587e+10

# %%
# Display random sample
print("\nRandom sample of 5 rows:")
data.sample(5, random_state=42)
# Out:
# Random sample of 5 rows:
#             Date          Open          High           Low         Close  \
# 869   25-02-2017   1170.410034   1174.849976   1124.589966   1143.839966
# 3420  20-02-2024  51777.726560  52945.050780  50792.312500  52284.875000
# 351   26-09-2015    235.076004    235.403000    233.358002    234.339996
# 927   24-04-2017   1209.630005   1250.939941   1209.630005   1250.150024
# 1820  04-10-2019   8259.494141   8260.055664   8151.236816   8205.939453
#
#          Adj Close        Volume
# 869    1143.839966  1.399610e+08
# 3420  52284.875000  3.335376e+10
# 351     234.339996  1.372410e+07
# 927    1250.150024  2.358060e+08
# 1820   8205.939453  1.313946e+10

# %%
# Ensure index is datetime (in case it isn't)
data.index = pd.to_datetime(data.index)

# Sort by date
data.sort_index(inplace=True)

print(f'Date Range    : {data.index.min().date()} → {data.index.max().date()}')
print(f'Total Days    : {(data.index.max() - data.index.min()).days}')
# Out:
# Date Range    : 1970-01-01 → 1970-01-01
# Total Days    : 0

# %% [markdown]
# ## Section 3 : Data Overview

# %%
# Column info
data.info()
print()
data.describe().round(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3566 entries, 1970-01-01 00:00:00 to 1970-01-01 00:00:00.000003565
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3566 non-null   object
#  1   Open       3566 non-null   float64
#  2   High       3566 non-null   float64
#  3   Low        3566 non-null   float64
#  4   Close      3566 non-null   float64
#  5   Adj Close  3566 non-null   float64
#  6   Volume     3566 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 222.9+ KB
#            Open      High       Low     Close  Adj Close        Volume
# count   3566.00   3566.00   3566.00   3566.00    3566.00  3.566000e+03
# mean   17130.77  17521.65  16713.15  17146.36   17146.36  1.746206e+10
# std    18911.21  19338.26  18441.41  18920.81   18920.81  1.917847e+10
# min      176.90    211.73    171.51    178.10     178.10  5.914570e+06
# 25%     1164.66   1186.74   1126.91   1166.92    1166.92  2.928932e+08
# 50%     8940.44   9202.83   8790.99   8987.82    8987.82  1.363268e+10
# 75%    28084.28  28531.55  27534.17  28148.96   28148.96  2.805912e+10
# max    73079.38  73750.07  71334.09  73083.50   73083.50  3.509680e+11

# %% [markdown]
# ## Section 4 : Data PreProcessing

# %%
# --- Missing Values ---
print('Missing Values:')
print(data.isnull().sum())
print(f'\nTotal missing: {data.isnull().sum().sum()}')
# Out:
# Missing Values:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
#
# Total missing: 0

# %%
# --- Duplicates ---
print(f'Duplicate date entries: {data.index.duplicated().sum()}')
df = data[~data.index.duplicated(keep='first')]
# Out:
# Duplicate date entries: 0

# %%
# --- Drop Adj Close (same as Close for BTC) ---
df.drop(columns=['Adj Close'], inplace=True)

# %%
# --- Ensure numeric types ---
for col in df.columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')
df.ffill(inplace=True)

# %%
# --- Outlier check via Z-score ---
z_scores = np.abs(stats.zscore(df[['Close', 'Volume']]))
outliers = (z_scores > 4).sum()
print(f'\nOutliers (|Z| > 4):')
print(outliers)
print('\n Preprocessing complete!')
df.shape
# Out:
# Outliers (|Z| > 4):
# 11
#
#  Preprocessing complete!
# (3566, 6)

# %%
# --- Resample for multi-frequency analysis ---
df_weekly  = df['Close'].resample('W').mean()
df_monthly = df['Close'].resample('ME').mean()
df_quarterly = df['Close'].resample('QE').mean()

print(f'Daily    : {len(df)} records')
print(f'Weekly   : {len(df_weekly)} records')
print(f'Monthly  : {len(df_monthly)} records')
print(f'Quarterly: {len(df_quarterly)} records')
# Out:
# Daily    : 3566 records
# Weekly   : 1 records
# Monthly  : 1 records
# Quarterly: 1 records
